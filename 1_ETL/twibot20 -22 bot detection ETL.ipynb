# %% [markdown]
# # Load and unzip files

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
! ls "/content/gdrive/MyDrive/Colab Notebooks/MO436/data/TwiBot-20-Format22.zip"
# Out:
# '/content/gdrive/MyDrive/Colab Notebooks/MO436/data/TwiBot-20-Format22.zip'

# %%
! unzip  "/content/gdrive/MyDrive/Colab Notebooks/MO436/data/TwiBot-20-Format22.zip"
# Out:
# Archive:  /content/gdrive/MyDrive/Colab Notebooks/MO436/data/TwiBot-20-Format22.zip
#    creating: Twibot-20/
#   inflating: Twibot-20/node.json
#   inflating: Twibot-20/split.csv
#   inflating: Twibot-20/user_info.pt
#   inflating: Twibot-20/test.ipynb
#   inflating: Twibot-20/edge.csv
#   inflating: Twibot-20/label.csv

# %%
! mv "/content/Twibot-20" "./gdrive/MyDrive/Colab Notebooks/MO436/data/Twibot-20"

# %%
# !ls "./gdrive/MyDrive/Colab Notebooks/MO436/data/Twibot-20"
# Out:
# edge.csv  label.csv  node.json	split.csv  test.ipynb  user_info.pt

# %% [markdown]
# # Make parquet files

# %% [markdown]
# ## Twibot 20

# %%
# !pip install ijson -q
# Out:
# Collecting ijson
#   Downloading ijson-3.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.8/111.8 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: ijson
# Successfully installed ijson-3.2.3

# %%
import pandas as pd
from pathlib import Path

data_folder_path = Path("./gdrive/MyDrive/Colab Notebooks/MO436/data/Twibot-20")
# data_folder_node_path = Path("./gdrive/MyDrive/Colab Notebooks/MO436/data/Twibot-20/node")

# %%
import ijson
from tqdm import tqdm

def _handle_mixed_tweet_profile_dataset(df):

  if ("text" in df.columns) and ("name" in df.columns):
    return (
        df[df["text"].isna()].drop(columns = ["text"]),
        df[df["text"].notna()][["id","text"]]
        )

  elif (not "text" in df.columns) and ("name" in df.columns):
    return (
        df,
        pd.DataFrame()
        )

  else:
    return (
        pd.DataFrame(),
        df
    )

def _write_profile_and_tweet_data(items, saving_folder, saving_prefix, p):
  df = pd.DataFrame.from_records(items)
  profile_df, tweet_df = _handle_mixed_tweet_profile_dataset(df)

  if len(profile_df)  > 0:
    (profile_df.to_parquet(saving_folder/"profile"/f"{saving_prefix}.part{p}.parquet"))
  if len(tweet_df)  > 0:
    (tweet_df.to_parquet(saving_folder/"tweets"/f"{saving_prefix}.part{p}.parquet"))

  return

def parse_json_by_chunks(file_path, saving_path, saving_prefix, chunksize = 2_000_000):

  saving_folder = Path(saving_path)
  (saving_folder/"profile").mkdir(parents=True, exist_ok=True)
  (saving_folder/"tweets").mkdir(parents=True, exist_ok=True)
  # Open the JSON file
  with open(file_path, 'r') as file:
    # Parse the JSON objects one by one
    parser = ijson.items(file, 'item')
    # Iterate over the JSON objects
    i = 0
    p = 0
    items = []
    for item in tqdm(parser):
        # Process each JSON object as needed
        items.append(item)
        if i >= chunksize:
          _write_profile_and_tweet_data(
              items, saving_folder, saving_prefix, p)
          p+=1
          #reset counters
          i=0
          items=[]
        i+=1

    if len(items) > 0:
      _write_profile_and_tweet_data(items, saving_folder, saving_prefix, p)

  return saving_folder

# %%
parse_json_by_chunks(
    file_path = data_folder_path/"node.json",
    saving_path = data_folder_path/"node",
    saving_prefix = "node",
    chunksize = 5_000_000,
    )

# %%
list((data_folder_path/"node/profile").glob("*"))
# Out:
# [PosixPath('gdrive/MyDrive/Colab Notebooks/MO436/data/Twibot-20/node/profile/node.part0.parquet')]

# %%
list((data_folder_path/"node/tweets").glob("*"))
# Out:
# [PosixPath('gdrive/MyDrive/Colab Notebooks/MO436/data/Twibot-20/node/tweets/node.part0.parquet'),
#  PosixPath('gdrive/MyDrive/Colab Notebooks/MO436/data/Twibot-20/node/tweets/node.part1.parquet'),
#  PosixPath('gdrive/MyDrive/Colab Notebooks/MO436/data/Twibot-20/node/tweets/node.part2.parquet'),
#  PosixPath('gdrive/MyDrive/Colab Notebooks/MO436/data/Twibot-20/node/tweets/node.part3.parquet'),
#  PosixPath('gdrive/MyDrive/Colab Notebooks/MO436/data/Twibot-20/node/tweets/node.part4.parquet'),
#  PosixPath('gdrive/MyDrive/Colab Notebooks/MO436/data/Twibot-20/node/tweets/node.part5.parquet'),
#  PosixPath('gdrive/MyDrive/Colab Notebooks/MO436/data/Twibot-20/node/tweets/node.part6.parquet')]

# %% [markdown]
# ## Join profile with other data

# %%
edge_df = pd.read_csv(data_folder_path/"edge.csv")
label_df = pd.read_csv(data_folder_path/"label.csv")
split_df = pd.read_csv(data_folder_path/"label.csv")

# %%
edge_df.relation.unique()
# Out:
# array(['post', 'friend', 'follow'], dtype=object)

# %% [markdown]
# ## Twibot 22

# %% [markdown]
# # Explore Data

# %%
import pandas as pd
from pathlib import Path

# %%
# Out:
# /content

# %%
domain_data_file = "Twi20_domain.parquet"
neighbor_data_file = "Twi20_neighbor.parquet"
label_data_file = "Twi20_label.parquet"
profile_data_file = "Twi20_profile.parquet"
tweets_data_file = "Twi20_tweets.parquet"

# %%
label_df = pd.read_parquet(data_folder_path/label_data_file)
domain_df = pd.read_parquet(data_folder_path/domain_data_file)
neighbor_df = pd.read_parquet(data_folder_path/neighbor_data_file)
profile_df = pd.read_parquet(data_folder_path/profile_data_file)
tweet_df = pd.read_parquet(data_folder_path/tweets_data_file)

# %%
profile_df
# Out:
#                        ID                                              name  \
# 0                17461978                                             SHAQ
# 1     1297437077403885568                                 Jennifer Fishpaw
# 2                17685258                                    Brad Parscale
# 3                15750898                                 FOX 13 Tampa Bay
# 4              1659167666                                Vonte The Plug 🎤🔌
# ...                   ...                                               ...
# 9456            452754350                                     Alan Reifman
# 9457   850435801687183362  Junk Wax Investment Services ($19.99 Per Month)
# 9458           2188795745                                                B
# 9459            940687680                                        bilal koç
# 9460           3385331674                              If You Build It  ⚾️
#
#            screen_name                 location  \
# 0                SHAQ              Orlando, FL
# 1     JenniferFishpaw
# 2            parscale                  Florida
# 3           FOX13News                Tampa, FL
# 4      VonteThePlugNC   Jacksonville Beach, FL
# ...                ...                      ...
# 9456      AlanReifman           Lubbock, Texas
# 9457   CardsFromAttic          JunkWaxSylvania
# 9458        bkgreen09            United States
# 9459        bilalko14
# 9460    IfYouBuildIt_              New England
#
#                                        profile_location  \
# 0     {'id': '55b4f9e5c516e0b6', 'url': 'https://api...
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4     {'id': '5e281c17a74c170f', 'url': 'https://api...
# ...                                                 ...
# 9456                                              None
# 9457                                              None
# 9458                                              None
# 9459                                              None
# 9460                                              None
#
#                                             description protected  \
# 0     VERY QUOTATIOUS, I PERFORM RANDOM ACTS OF SHAQ...    False
# 1                                                          False
# 2     Owner @ Parscale Strategy. Senior Advisor Digi...    False
# 3     Bringing you the important stuff like breaking...    False
# 4     MOTIVATION 3 OUT NOW 🔥 Singles: ‘Lil Shawdy’ &...    False
# ...                                                 ...       ...
# 9456  Texas Tech professor of human devt and family ...    False
# 9457  Satirizing the sports card industry one tweet ...    False
# 9458                                                       False
# 9459                                                       False
# 9460  We're a father/son duo sharing the love we pos...    False
#
#      followers_count friends_count listed_count  ...  \
# 0          15349596           692        45568   ...
# 1                 0            44            0   ...
# 2            762839           475         3201   ...
# 3            327587          4801         1744   ...
# 4             13324           647           44   ...
# ...              ...           ...          ...  ...
# 9456           7760          8104          106   ...
# 9457           8446           408           55   ...
# 9458            309          1961            3   ...
# 9459            154          1019            0   ...
# 9460             68           927            0   ...
#
#                                       profile_image_url  \
# 0     http://pbs.twimg.com/profile_images/1673907275...
# 1     http://pbs.twimg.com/profile_images/1297437406...
# 2     http://pbs.twimg.com/profile_images/1295453225...
# 3     http://pbs.twimg.com/profile_images/1293193013...
# 4     http://pbs.twimg.com/profile_images/1181662400...
# ...                                                 ...
# 9456  http://pbs.twimg.com/profile_images/4718599734...
# 9457  http://pbs.twimg.com/profile_images/1300649646...
# 9458  http://pbs.twimg.com/profile_images/1168654618...
# 9459  http://pbs.twimg.com/profile_images/2840708085...
# 9460  http://pbs.twimg.com/profile_images/6233083430...
#
#                                 profile_image_url_https profile_link_color  \
# 0     https://pbs.twimg.com/profile_images/167390727...            2FC2EF
# 1     https://pbs.twimg.com/profile_images/129743740...            1DA1F2
# 2     https://pbs.twimg.com/profile_images/129545322...            AB2316
# 3     https://pbs.twimg.com/profile_images/129319301...            0B2F8A
# 4     https://pbs.twimg.com/profile_images/118166240...            1DA1F2
# ...                                                 ...                ...
# 9456  https://pbs.twimg.com/profile_images/471859973...            0084B4
# 9457  https://pbs.twimg.com/profile_images/130064964...            1DA1F2
# 9458  https://pbs.twimg.com/profile_images/116865461...            3B94D9
# 9459  https://pbs.twimg.com/profile_images/284070808...            1DA1F2
# 9460  https://pbs.twimg.com/profile_images/623308343...            4A913C
#
#      profile_sidebar_border_color profile_sidebar_fill_color  \
# 0                         181A1E                     252429
# 1                         C0DEED                     DDEEF6
# 2                         FFFFFF                     FFFFFF
# 3                         FFFFFF                     E8EEF0
# 4                         C0DEED                     DDEEF6
# ...                           ...                        ...
# 9456                      FFFFFF                     DDEEF6
# 9457                      C0DEED                     DDEEF6
# 9458                      000000                     000000
# 9459                      C0DEED                     DDEEF6
# 9460                      000000                     000000
#
#      profile_text_color profile_use_background_image has_extended_profile  \
# 0               666666                         True                False
# 1               333333                         True                 True
# 2               666666                        False                False
# 3               333333                         True                False
# 4               333333                         True                False
# ...                 ...                          ...                  ...
# 9456            333333                         True                False
# 9457            333333                         True                False
# 9458            000000                        False                 True
# 9459            333333                         True                False
# 9460            000000                        False                False
#
#      default_profile default_profile_image
# 0             False                 False
# 1              True                 False
# 2             False                 False
# 3             False                 False
# 4              True                 False
# ...              ...                   ...
# 9456          False                 False
# 9457           True                 False
# 9458          False                 False
# 9459           True                 False
# 9460          False                 False
#
# [9461 rows x 35 columns]
